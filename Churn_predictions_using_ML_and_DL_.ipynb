# %% [markdown]
# <a href="https://colab.research.google.com/github/SumeetCEH/SumeetsAI/blob/main/Churn_predictions_using_ML_and_DL_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('/content/Telco-Customer-Churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.size
# Out:
# 147903

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.histplot(df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
sns.countplot(df['Churn'])
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts().index
# Out:
# Index(['No', 'Yes'], dtype='object', name='Churn')

# %%
label_df=df['Churn'].value_counts().index

# %%
value_df=df['Churn'].value_counts().values

# %%
plt.pie(x=value_df,labels=label_df,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7e592e8450>,
# ...
#  [Text(-0.7393678155529122, 0.8144539479458093, 'No'),
#   Text(0.7393680809356543, -0.8144537070291521, 'Yes')],
#  [Text(-0.40329153575613386, 0.4442476079704414, '73.46%'),
#   Text(0.40329168051035685, -0.44424747656135566, '26.54%')])

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
sns.boxplot(x='Churn',y='MonthlyCharges',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
sns.pairplot(df)

# %%
df.corr(numeric_only=True)
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b34e1_row0_col0, #T_b34e1_row1_col1, #T_b34e1_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b34e1_row0_col1, #T_b34e1_row0_col2, #T_b34e1_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b34e1_row1_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b34e1_row2_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b34e1_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# </style>
# <table id="T_b34e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b34e1_level0_col0" class="col_heading level0 col0" >SeniorCitizen</th>
#       <th id="T_b34e1_level0_col1" class="col_heading level0 col1" >tenure</th>
#       <th id="T_b34e1_level0_col2" class="col_heading level0 col2" >MonthlyCharges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in df.columns:
  if df[column].dtype==object:
    df[column]=le.fit_transform(df[column].astype(str))

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df=df.drop('customerID',axis=1)

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int64
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int64
#  3   Dependents        7043 non-null   int64
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int64
#  6   MultipleLines     7043 non-null   int64
#  7   InternetService   7043 non-null   int64
#  8   OnlineSecurity    7043 non-null   int64
#  9   OnlineBackup      7043 non-null   int64
#  10  DeviceProtection  7043 non-null   int64
#  11  TechSupport       7043 non-null   int64
#  12  StreamingTV       7043 non-null   int64
#  13  StreamingMovies   7043 non-null   int64
#  14  Contract          7043 non-null   int64
#  15  PaperlessBilling  7043 non-null   int64
# ...

# %%
sm= SMOTE(random_state=42)

# %%
X=df.drop('Churn',axis=1)

# %%
y=df['Churn']

# %%
X,y=sm.fit_resample(X,y)

# %%
X.shape
# Out:
# (10348, 19)

# %%
y.shape
# Out:
# (10348,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test  = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (6933, 19)

# %%
X_test.shape
# Out:
# (3415, 19)

# %%
y_test.shape
# Out:
# (3415,)

# %%
y_train.shape
# Out:
# (6933,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8465592972181551

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.811420204978038

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.779502196193265

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN=KNeighborsClassifier()

# %%
KNN.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=KNN.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 0, 1])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7648609077598829

# %% [markdown]
# **DEEP LEARNING**

# %%
import keras

# %%
model=keras.Sequential()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(
    keras.Input(
        shape=(19,),
        batch_size=32
    )
)

# %%
model.add(
    keras.layers.Dense(
        128,
        activation='relu'
    )
)

# %%
model.add(
    keras.layers.Dense(
        1,
        activation='sigmoid'
    )
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (32, 128)              │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
from gc import callbacks
callback=keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    patience=3,
    restore_best_weights=True
)

# %%
model.fit(
    x=X_train,
    y=y_train,
    batch_size=32,
    epochs=100,
    verbose="auto",
    validation_data=(X_test,y_test),
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6165 - loss: 21.1114 - val_accuracy: 0.7637 - val_loss: 0.6751
# Epoch 2/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6698 - loss: 1.6761 - val_accuracy: 0.6571 - val_loss: 1.4728
# Epoch 3/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7182 - loss: 1.0036 - val_accuracy: 0.7057 - val_loss: 1.2553
# Epoch 4/100
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7274 - loss: 1.0026 - val_accuracy: 0.5731 - val_loss: 2.1764
