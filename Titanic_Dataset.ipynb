# %% [markdown]
# <a href="https://colab.research.google.com/github/SumeetCEH/SumeetsAI/blob/main/Titanic_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
temp=df['age'].median()

# %%
temp
# Out:
# 28.0

# %%
df['age']=df['age'].fillna(temp)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=df.drop('deck',axis=1)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df['embarked'].dropna(inplace=True)

# %%
df['embark_town'].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
sns.countplot(df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(df['fare'])
# Out:
# <Axes: ylabel='fare'>

# %%
sns.barplot(data=df,x='sex',y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(df)

# %%
temp=df.corr(numeric_only=True)

# %%
temp
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# age        -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# sibsp      -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.247704 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.171647 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.247704  0.171647
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(temp,annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
df['class']=le.fit_transform(df['class'])

# %%
df['embarked']=le.fit_transform(df['embarked'])

# %%
df['age']=le.fit_transform(df['age'])

# %%
df['who']=le.fit_transform(df['who'])

# %%
df['adult_male']=le.fit_transform(df['adult_male'])

# %%
df['survived']=le.fit_transform(df['survived'])

# %%
df['alive']=le.fit_transform(df['alive'])

# %%
df['alone']=le.fit_transform(df['alone'])

# %%
df['embark_town']=le.fit_transform(df['embark_town'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    int64
#  3   age          891 non-null    int64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    int64
#  8   class        891 non-null    int64
#  9   who          891 non-null    int64
#  10  adult_male   891 non-null    int64
#  11  embark_town  891 non-null    int64
#  12  alive        891 non-null    int64
#  13  alone        891 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 97.6 KB

# %%
X=df.drop('survived',axis=1)

# %%
y=df['survived']

# %%
X
# Out:
#      pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         3    1   28      1      0   7.2500         2      2    1
# 1         1    0   51      1      0  71.2833         0      0    2
# 2         3    0   34      0      0   7.9250         2      2    2
# 3         1    0   47      1      0  53.1000         2      0    2
# 4         3    1   47      0      0   8.0500         2      2    1
# ..      ...  ...  ...    ...    ...      ...       ...    ...  ...
# 886       2    1   35      0      0  13.0000         2      1    1
# 887       1    0   24      0      0  30.0000         2      0    2
# 888       3    0   36      1      2  23.4500         2      2    2
# 889       1    1   34      0      0  30.0000         0      0    1
# 890       3    1   42      0      0   7.7500         1      2    1
#
#      adult_male  embark_town  alive  alone
# 0             1            2      0      0
# 1             0            0      1      0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (668, 13)

# %%
X_test.shape
# Out:
# (223, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 100.0

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)

# %%
neigh.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=neigh.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 77.13004484304933

# %%
temp=df.corr(numeric_only=True)

# %%
sns.heatmap(temp,annot=True)
# Out:
# <Axes: >

# %%
pip install --upgrade keras
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
# ...

# %%
import keras
print(keras.__version__)
# Out:
# 3.9.2

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(13,)))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                │ (None, 16)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 801 (3.13 KB)
#  Trainable params: 801 (3.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
Model: "sequential_1"

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    x=X_train,
    y=y_train,
    batch_size=32,
    epochs=50,
    verbose="auto",
    callbacks=None,
    validation_split=0.0,
    validation_data=(X_test,y_test)
)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7430 - loss: 0.4883 - val_accuracy: 0.8206 - val_loss: 0.4303
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8182 - loss: 0.4168 - val_accuracy: 0.8610 - val_loss: 0.4143
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8620 - loss: 0.4180 - val_accuracy: 0.8610 - val_loss: 0.3971
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8765 - loss: 0.3759 - val_accuracy: 0.8834 - val_loss: 0.3916
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8838 - loss: 0.3697 - val_accuracy: 0.8834 - val_loss: 0.3761
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8680 - loss: 0.3842 - val_accuracy: 0.8834 - val_loss: 0.3663
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8773 - loss: 0.3784 - val_accuracy: 0.9193 - val_loss: 0.3396
# Epoch 8/50
# ...

# %%
model.evaluate(
    x=X_test,
    y=y_test,
    batch_size=32,
    verbose="auto"
)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0246
# [0.027419818565249443, 1.0]
