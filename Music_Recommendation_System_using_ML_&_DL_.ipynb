# %% [markdown]
# <a href="https://colab.research.google.com/github/SumeetCEH/SumeetsAI/blob/main/Music_Recommendation_System_using_ML_%26_DL_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/tcc_ceds_music.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 artist_name                     track_name  release_date  \
# 28367       82447     mack 10                10 million ways          2019
# 28368       82448      m.o.p.  ante up (robbin hoodz theory)          2019
# 28369       82449        nine                  whutcha want?          2019
# 28370       82450  will smith                         switch          2019
# 28371       82451       jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  len  \
# 28367  hip hop  cause fuck leave scar tick tock clock come kno...   78
# 28368  hip hop  minks things chain ring braclets yap fame come...   67
# 28369  hip hop  get ban get ban stick crack relax plan attack ...   77
# 28370  hip hop  check check yeah yeah hear thing call switch g...   67
# 28371  hip hop  remix killer alive remix thriller trap bitch s...   83
#
#          dating  violence  world/life  ...   sadness  feelings  danceability  \
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  len  \
# ...

# %%
sns.countplot(df['genre'])
# Out:
# <Axes: xlabel='count', ylabel='genre'>

# %%
top_artists = df.groupby('artist_name').size().sort_values(ascending=False).head(10)

# %%
top_artists
# Out:
# artist_name
# johnny cash        190
# ella fitzgerald    188
# dean martin        146
# willie nelson      131
# george jones       107
# elvis presley       97
# dolly parton        96
# waylon jennings     95
# george strait       92
# nina simone         82
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_artists.values,y=top_artists.index,palette='viridis')
plt.title('Top 10 Artists by Number of Songs')
plt.xlabel('Number of Songs')
plt.ylabel('Artist Name')
plt.show()
# Out:
# <ipython-input-10-6b16cd786822>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_artists.values,y=top_artists.index,palette='viridis')

# %%
plt.pie(labels=top_artists.index,x=top_artists.values,autopct='%1.2f%%')
plt.show()

# %%
df['combined_features'] = (
    df['genre'].fillna('') + ' ' +
    df['artist_name'].fillna('') + ' ' +
    df['track_name'].fillna('')
)

# %%
df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  len  \
# ...

# %%
df['combined_features']
# Out:
# 0                     pop mukesh mohabbat bhi jhoothi
# 1                         pop frankie laine i believe
# 2                                 pop johnnie ray cry
# 3                            pop pérez prado patricia
# 4         pop giorgos papadopoulos apopse eida oneiro
#                              ...
# 28367                 hip hop mack 10 10 million ways
# 28368    hip hop m.o.p. ante up (robbin hoodz theory)
# 28369                      hip hop nine whutcha want?
# 28370                       hip hop will smith switch
# 28371                            hip hop jeezy r.i.p.
# Name: combined_features, Length: 28372, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 132224 stored elements and shape (28372, 14090)>

# %%
def get_recommendations(song_title, df, cosine_sim, top_n=10):
    # Get the index of the song that matches the title
    idx = df[df['track_name'] == song_title].index
    print(idx)
    print(song_title)
    print(df)

    if len(idx) == 0:
        print("Song not found in the dataset.")
        return

    idx = idx[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]
    song_indices = [i[0] for i in sim_scores]
    recommendations = df.iloc[song_indices]
    return recommendations

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
recommended_songs = get_recommendations('cry', df, cosine_sim, top_n=10)
print(recommended_songs[['track_name', 'artist_name', 'genre']])
# Out:
# Index([2, 426, 649, 4700, 14249, 20294], dtype='int64')
# cry
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
# ...
