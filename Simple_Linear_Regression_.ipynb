# %% [markdown]
# <a href="https://colab.research.google.com/github/SumeetCEH/SumeetsAI/blob/main/Simple_Linear_Regression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/tvmarketing.csv")

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df.tail()
# Out:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
df.describe().T
# Out:
#        count      mean        std  min     25%     50%      75%    max
# TV     200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Sales  200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.shape
# Out:
# (200, 2)

# %%
df.size
# Out:
# 400

# %%
df.dtypes
# Out:
# TV       float64
# Sales    float64
# dtype: object

# %%
df.dtypes
# Out:
# TV       float64
# Sales    float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.histplot(data=df,x="TV")
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(data=df,x="Sales")
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
df.corr()
# Out:
#              TV     Sales
# TV     1.000000  0.782224
# Sales  0.782224  1.000000

# %%
sns.scatterplot(data=df,x='TV',y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.boxplot(df['Sales'])
# Out:
# <Axes: ylabel='Sales'>

# %%
res=df.corr()

# %%
sns.heatmap(res,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.sort_values(by='Sales',ascending=False)[:5]
# Out:
#         TV  Sales
# 175  276.9   27.0
# 183  287.6   26.2
# 198  283.6   25.5
# 36   266.9   25.4
# 98   289.7   25.4

# %%
df.sort_values(by='Sales',ascending=True)[:5]
# Out:
#        TV  Sales
# 130   0.7    1.6
# 155   4.1    3.2
# 8     8.6    4.8
# 78    5.4    5.3
# 108  13.1    5.3

# %%
X=df[['TV']]

# %%
y=df['Sales']

# %%
X
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([14.94164546, 16.48965233, 21.19154233,  7.63080932, 17.69044269,
#        10.68824343, 17.5216569 ,  9.47780816, 17.79171417, 15.51069472,
#         8.58565468,  9.77680014, 18.37523078,  7.32699489, 13.79390206,
#        15.2743946 ,  7.41862147, 16.59574625, 10.69788834, 18.51508186,
#        18.13410821, 10.33620449,  8.89911401, 19.16611279, 10.39407391,
#         9.64659396, 17.36251601, 13.78425716, 11.27176004,  7.47166843,
#        16.70184018, 10.40371881, 16.65843812,  7.88157679, 20.60320327,
#        18.55366147,  9.39582649, 20.26563168, 12.71849542,  8.39275662,
#        12.66062601, 15.60232129,  9.14505902, 10.07096967, 17.86887339,
#         8.90875891, 10.47123313, 14.17005326, 12.11086656, 10.74611285,
#        10.83773942, 15.18759048,  7.48613578,  7.44273372, 10.7509353 ,
#        13.30683448, 10.60626176, 21.03722388,  8.01178297, 16.59574625,
#        20.77681152, 15.98329494, 12.51113002,  8.21432593, 21.0854484 ,
#         8.00213807])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6236886078089201

# %%
from sklearn.metrics import mean_squared_error
